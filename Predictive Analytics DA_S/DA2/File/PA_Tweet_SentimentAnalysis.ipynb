# %% [markdown]
# #DA2
# Twitter scrapping \
# GUNA SHANKAR S \
# 20MIA1162

# %%
#!/usr/bin/env python
# coding: utf-8

# In[6]:


import pandas as pd
import numpy as np 
import re 
import matplotlib.pyplot as plt

import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk import sent_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
from textblob import TextBlob
from wordcloud import WordCloud, STOPWORDS
# !pip install pandas openpyxl
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
stand_df = pd.read_csv("/content/tweets_election.csv",index_col=0) 
# Tweet = stand_df.filter(['tweet'])
# Tweet.head(10)
stand_df.head(10)
# Out:
#     geo                                               text             user  \
# 3   NaN   After the confrontation that cost Walter Wall...    wheresestela1
# 6   NaN   "COVID-19 is still raging. Trump is still lyi...  TheFemaleYungin
# 11  NaN   Donald Trump Jr.: "Why aren't they talking ab...  KathrynTomashu1
# 15  NaN  Letâ€™s not forget who created these problems....         ajserino
# 16  NaN   There is no greater supporter of Donald Trump...     SpeakBravely
# 18  NaN  'A vote for Donald Trump is a vote against the...    TMScarletFire
# 25  NaN   There is no greater supporter of Donald Trump...        mwamsley5
# 29  NaN   The same people who are outraged at AOC for s...     SpeakBravely
# 30  NaN   Donald Trump is on track to become the worst ...   XchargerFan619
# 38  NaN  It is Friday, October 30, 2020. One citizen, I...  eachlifeinplace
#
#                      location       Subject          state
# 3                  New Jersey  Donald Trump     New Jersey
# ...

# %%
# create a function to clean the tweets
def cleanTxt(text):
    #Remove @mentions and replace with blank
    text = re.sub(r'@[A-Za-z0–9]+', '', text) 
    
    #Remove the '#' symbol, replace with blank
    text = re.sub(r'#', '', text) 
    
    #Removing RT, replace with blank
    text = re.sub(r'RT[\s]+', '', text) 
    
    #Remove the hyperlinks
    text = re.sub(r'https?:\/\/\S+', '', text) 
 
    return text
# clean the text
stand_df['text']= stand_df['text'].apply(cleanTxt)
#Show the clean text
stand_df


# In[10]:


def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

#Cleaning the text
stand_df['text']= stand_df['text'].apply(remove_emoji)

#Show the clean text
stand_df

# In[11]:

stand_df.isnull().sum()
stand_df.drop(['geo'],axis=1)

# In[ ]:
# Out:
#                                                    text             user  \
# 3      After the confrontation that cost Walter Wall...    wheresestela1
# 6      "COVID-19 is still raging. Trump is still lyi...  TheFemaleYungin
# 11     Donald Trump Jr.: "Why aren't they talking ab...  KathrynTomashu1
# 15    Letâ€™s not forget who created these problems....         ajserino
# 16     There is no greater supporter of Donald Trump...     SpeakBravely
# ...                                                 ...              ...
# 1488   Donald Trump is just one big COVID19 super sp...     karen_brioso
# 1490      Obama was a black voted by all! He reigned...          ArcYuyu
# 1491  Tony Bobulinski Communicates A Message To Joe ...        USMCMIL03
# 1492  After campaigning in 2016 to lift up the â€˜fo...         JoeBiden
# 1495  But yes. Letâ€™s all run and vote in corrupt, ...   ZeroIndulgence
#
#                        location       Subject          state
# ...
